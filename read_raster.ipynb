# %%
import pystac
items = pystac.ItemCollection.from_file("search.json")

# %%
import rioxarray
raster_ams_b9 = rioxarray.open_rasterio(items[0].assets["nir09"].href)

# %%
raster_ams_b9.plot()

# %%
raster_ams_b9.plot(robust=True)

# %%
raster_ams_overview = rioxarray.open_rasterio(items[0].assets["visual"].href, overview_level=1)
raster_ams_overview
# Out:
# <xarray.DataArray (band: 3, y: 2745, x: 2745)> Size: 23MB
# [22605075 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 24B 1 2 3
#   * x            (x) float64 22kB 6e+05 6.001e+05 ... 7.097e+05 7.098e+05
#   * y            (y) float64 22kB 5.9e+06 5.9e+06 5.9e+06 ... 5.79e+06 5.79e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     OVR_RESAMPLING_ALG:  AVERAGE
#     AREA_OR_POINT:       Area
#     _FillValue:          0
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
raster_ams_overview.plot.imshow(size=5, aspect=1)
